# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Define parameters
alpha, beta, gamma, delta = 1.0, 1.0, 1.0, 1.0  # Example parameters
N = 10  # Number of cells

# Define the system of equations
def system(t, y):
    u = y[:N]  # First N variables are u_i
    v = y[N:]  # Last N variables are v_i
    
    du_dt = np.zeros(N)
    dv_dt = np.zeros(N)

    for i in range(N):
        # Periodic boundary conditions
        left = (i - 1) % N
        right = (i + 1) % N

        # Example equations (adjust to your model)
        du_dt[i] = alpha * u[i] - beta * v[i] + (u[right] - u[left])
        dv_dt[i] = gamma * u[i] - delta * v[i] + (v[right] - v[left])

    return np.concatenate([du_dt, dv_dt])

# Initial conditions
u0 = np.random.rand(N)  # Random initial values
v0 = np.random.rand(N)
y0 = np.concatenate([u0, v0])

# Time span
t_span = (0, 10)
t_eval = np.linspace(0, 10, 200)

# Solve the system
sol = solve_ivp(system, t_span, y0, t_eval=t_eval, method='RK45')

# Plot results
plt.figure(figsize=(10, 6))
for i in range(N):
    plt.plot(sol.t, sol.y[i], label=f'u{i}')
plt.title('Evolution of u variables')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
for i in range(N, 2*N):
    plt.plot(sol.t, sol.y[i], label=f'v{i-N}')
plt.title('Evolution of v variables')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example: Generate random time series data
# Shape: (time_steps, num_cells)
time_steps = 100  # Number of time points
num_cells = 10  # Number of cells
data = np.random.rand(time_steps, num_cells)  # Replace with your actual data

# Create the heatmap-like plot
plt.figure(figsize=(10, 8))

# Plot the data as an image with the time on the y-axis and cells on the x-axis
plt.imshow(data, aspect='auto', cmap='viridis', interpolation='nearest')

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Value of x')

# Add labels
plt.xlabel('Cells')
plt.ylabel('Time')
plt.title('Time Series Heatmap of Random Variable (x)')

# Set x-ticks for each cell
plt.xticks(ticks=np.arange(num_cells), labels=np.arange(1, num_cells + 1))

# Show the plot
plt.show()
